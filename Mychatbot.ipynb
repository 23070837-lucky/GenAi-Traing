# %%
#Data Loading first
from langchain_community.document_loaders import TextLoader
loadder =TextLoader('qgissafebearingcapcity.txt',encoding="utf-8")
loadder

# %%
pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain_community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain_community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.0 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.3 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-text-splitters-1.1.2 langchain_community-0.4.2 pydantic-settings-2.14.2 requests-2.34.2

# %%
text_documents = loadder.load()
text_documents
# Out:
# [Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Abstract\n\nOne of the most important parameters in foundation engineering is the Soil Bearing Capacity (SBC). Accurate estimation of SBC is essential for designing safe, economical, and durable civil engineering structures.\n\nTraditional methods for determining SBC include:\n\nBorehole investigations\nStandard Penetration Test (SPT)\nLaboratory soil testing\n\nAlthough these methods provide reliable results, they are:\n\nTime-consuming\nCostly\nAvailable only at selected locations\n\nAs a result, SBC information is unavailable for many locations within a project area.\n\nTo overcome this limitation, Geographic Information System (GIS) technology can be used.\n\nGIS allows storage, analysis, visualization, and interpolation of spatial data.\n\nIn this study, QGIS is used to integrate:\n\nBorehole data\nSoil Bearing Capacity values\nGeographic coordinates\n\nThe collected data is spatially analyzed using interpolation techniques to estimate SBC values at locations where soil testing has not been performed.\n\nFinally, GIS-generated SBC maps classify the study area into:\n\nLow SBC zones\nMedium SBC zones\nHigh SBC zones\n\nThese maps help engineers during preliminary foundation planning while reducing investigation cost and time.\n\nKeywords\n\nSoil Bearing Capacity\nGIS\nQGIS\nBorehole Data\nSpatial Interpolation\nGeotechnical Engineering\n1. Introduction\n\nSoil Bearing Capacity is one of the most critical parameters in foundation engineering.\n\nFoundation types such as:\n\nIsolated Footing\nRaft Foundation\nPile Foundation\n\nare selected based on SBC.\n\nIf SBC is estimated incorrectly:\n\nStructure may fail.\nExcessive settlement may occur.\nConstruction cost increases.\n\nTraditional methods include:\n\nBorehole investigation\nStandard Penetration Test (SPT)\nLaboratory testing\n\nAlthough these methods provide accurate results, testing is performed only at limited locations because of:\n\nTime limitations\nHigh cost\nLimited accessibility\n\nConsequently, SBC information is unavailable across large portions of the project site.\n\nGIS offers a powerful platform to:\n\nStore spatial information\nAnalyze geotechnical data\nVisualize soil properties\nEstimate SBC at untested locations\n\nInterpolation techniques estimate unknown SBC values from nearby borehole data.\n\nThis research utilizes GIS technologies to estimate and map SBC across the study area using existing borehole and geotechnical information.\n\nThe generated SBC maps will assist engineers in identifying soil stability zones and selecting suitable foundation systems during preliminary project planning.\n\n2. Literature Review\n\nSeveral researchers have applied GIS and geotechnical data for subsurface modeling and Soil Bearing Capacity estimation.\n\nStudy 1: Civelekler et al. (2023)\n\nThe researchers developed:\n\nGIS-based 3D subsurface models\nIntegration of borehole and geophysical data\n\nMajor findings:\n\nBetter visualization of underground soil layers\nImproved understanding of subsurface conditions\nUseful where borehole information is limited\nStudy 2: KSCE Journal of Civil Engineering\n\nThe researchers applied:\n\nGIS interpolation techniques\n\nResults:\n\nContinuous estimation of soil properties\nBetter than conventional estimation methods\nUseful for preliminary planning\n\nLimitations:\n\nAccuracy depends on available borehole data.\nStudy 3: GIS-Based Soil Bearing Capacity Mapping\n\nVarious studies have used:\n\nIDW\nKriging\n\nfor predicting SBC.\n\nMajor findings:\n\nIdentification of weak soil zones\nIdentification of suitable foundation zones\nReduction in investigation cost\nReduction in planning time\nStudy 4: Integration of Borehole and Geophysical Data\n\nResearchers combined:\n\nBorehole information\nGeophysical survey data\n\nAdvantages:\n\nBetter subsurface characterization\nReduced uncertainty\nImproved reliability of geotechnical analysis\n\nResearchers ...

# %%
# Text solitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)

finalDocuments = textSplitter.split_documents(text_documents)
finalDocuments
# Out:
# [Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Abstract'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='One of the most important parameters in foundation engineering is the Soil Bearing Capacity (SBC). Accurate estimation of SBC is essential for designing safe, economical, and durable civil'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='and durable civil engineering structures.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Traditional methods for determining SBC include:\n\nBorehole investigations\nStandard Penetration Test (SPT)\nLaboratory soil testing\n\nAlthough these methods provide reliable results, they are:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Time-consuming\nCostly\nAvailable only at selected locations\n\nAs a result, SBC information is unavailable for many locations within a project area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='To overcome this limitation, Geographic Information System (GIS) technology can be used.\n\nGIS allows storage, analysis, visualization, and interpolation of spatial data.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='In this study, QGIS is used to integrate:\n\nBorehole data\nSoil Bearing Capacity values\nGeographic coordinates'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The collected data is spatially analyzed using interpolation techniques to estimate SBC values at locations where soil testing has not been performed.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Finally, GIS-generated SBC maps classify the study area into:\n\nLow SBC zones\nMedium SBC zones\nHigh SBC zones'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='These maps help engineers during preliminary foundation planning while reducing investigation cost and time.\n\nKeywords'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Keywords\n\nSoil Bearing Capacity\nGIS\nQGIS\nBorehole Data\nSpatial Interpolation\nGeotechnical Engineering\n1. Introduction'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Soil Bearing Capacity is one of the most critical parameters in foundation engineering.\n\nFoundation types such as:\n\nIsolated Footing\nRaft Foundation\nPile Foundation\n\nare selected based on SBC.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='If SBC is estimated incorrectly:\n\nStructure may fail.\nExcessive settlement may occur.\nConstruction cost increases.\n\nTraditional methods include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Borehole investigation\nStandard Penetration Test (SPT)\nLaboratory testing\n\nAlthough these methods provide accurate results, testing is performed only at limited locations because of:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Time limitations\nHigh cost\nLimited accessibility\n\nConsequently, SBC information is unavailable across large portions of the project site.\n\nGIS offers a powerful platform to:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Store spatial information\nAnalyze geotechnical data\nVisualize soil properties\nEstimate SBC at untested locations\n\nInterpolation techniques estimate unknown SBC values from nearby borehole data.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='This research utilizes GIS technologies to estimate and map SBC across the study area using existing borehole and geotechnical information.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated SBC maps will assist engineers in identifying soil stability zones and selecting suitable foundation systems during preliminary project planning.\n\n2. Literature Review'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Several researchers have applied GIS and geotechnical data for subsurface modeling and Soil Bearing Capacity estimation.\n\nStudy 1: Civelekler et al. (2023)\n\nThe researchers developed:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='GIS-based 3D subsurface models\nIntegration of borehole and geophysical data\n\nMajor findings:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Better visualization of underground soil layers\nImproved understanding of subsurface conditions\nUseful where borehole information is limited\nStudy 2: KSCE Journal of Civil Engineering'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The researchers applied:\n\nGIS interpolation techniques\n\nResults:\n\nContinuous estimation of soil properties\nBetter than conventional estimation methods\nUseful for preliminary planning\n\nLimitations:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Limitations:\n\nAccuracy depends on available borehole data.\nStudy 3: GIS-Based Soil Bearing Capacity Mapping\n\nVarious studies have used:\n\nIDW\nKriging\n\nfor predicting SBC.\n\nMajor findings:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Identification of weak soil zones\nIdentification of suitable foundation zones\nReduction in investigation cost\nReduction in planning time\nStudy 4: Integration of Borehole and Geophysical Data'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Researchers combined:\n\nBorehole information\nGeophysical survey data\n\nAdvantages:\n\nBetter subsurface characterization\nReduced uncertainty\nImproved reliability of geotechnical analysis'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Researchers concluded that GIS is an effective decision-support system but cannot completely replace detailed field investigations.\n\n\n\nResearch Paper – Part 2'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Title: GIS Based Estimation of Soil Bearing Capacity Using Borehole and Geophysical Data'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='TABLE 1: Summary of Previous Research Studies\nSr. No.\tAuthor / Year\tData Used\tMethodology\tKey Findings'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='1\tCivelekler et al. (2023)\tBorehole & Geophysical Data\tGIS-based 3D Subsurface Modeling\tImproved visualization and understanding of subsurface conditions'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='2\tKSCE Journal Study\tBorehole Data\tGIS Interpolation Techniques\tContinuous spatial estimation of soil properties'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='3\tVarious Researchers\tSBC & Borehole Data\tIDW and Kriging Methods\tEffective preliminary SBC mapping'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='4\tPrevious Geotechnical Studies\tBorehole + Geophysical Data\tIntegrated GIS Analysis\tReduced uncertainty in subsurface characterization\n3. Study Area'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The current research study was carried out in a selected area where sufficient and reliable borehole and soil investigation data were available.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Selection of the study area is very important because the accuracy of GIS analysis depends on:\n\nQuality of input data\nNumber of boreholes\nSpatial distribution of boreholes'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The study area represents an urban/semi-urban region where infrastructure development is increasing.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Since different soil types exist across the area, Soil Bearing Capacity also varies from place to place.\n\nThe study area boundary was defined using:\n\nLatitude\nLongitude'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Latitude\nLongitude\n\nThese coordinates help accurately position borehole locations in QGIS.\n\nA base map was created using:\n\nOpenStreetMap\nSatellite imagery\n\nThe base map provides information about:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Roads\nBuildings\nNearby landmarks\nBorehole locations\n\nThis improves visualization and understanding of spatial relationships.\n\n4. Data Used\n\nThe research integrates geotechnical and spatial datasets.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The success of GIS analysis depends on:\n\nAccurate data\nConsistent data\nWell-organized database\nPrimary Data\n\nThe primary dataset consists of:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Soil Bearing Capacity (SBC)\nBorehole reports\nStandard Penetration Test (SPT) data\nLaboratory soil test results'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content="Each SBC value represents the soil's ability to support structural loads at a specific location.\n\nGeographic Data\n\nEvery borehole location contains:\n\nLatitude\nLongitude"),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Latitude\nLongitude\n\nThese coordinates allow QGIS to accurately plot each borehole on the map while maintaining proper spatial relationships.\n\nSupporting Data'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Supporting Data\n\nWhere available, the following information is also included:\n\nSoil type\nSubsurface conditions\nGeological information'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='These datasets help establish correlations between different locations and improve SBC interpretation.\n\nSecondary Data\n\nSecondary datasets include:\n\nBase maps\nSatellite imagery\nOpenStreetMap layers'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='These datasets provide geographical context for the study.\n\n5. Methodology\n\nThe methodology focuses on estimating Soil Bearing Capacity over the entire study area using QGIS.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The process follows a systematic workflow.\n\n5.1 Collection and Preparation of Data\n\nThe first step involves collecting SBC values from:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Borehole reports\nGeotechnical investigation reports\nSoil testing reports\n\nThe collected data is checked carefully for:\n\nErrors\nMissing values\nInconsistencies\n\nEach SBC value is linked with:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Latitude\nLongitude\n\nThe data is organized in spreadsheet format for easy import into QGIS.\n\n5.2 Import of Data into QGIS\n\nThe prepared dataset is imported into QGIS using the:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Add Delimited Text Layer\n\nLatitude and longitude coordinates are used to generate borehole point locations.\n\nEach point contains:\n\nBorehole ID\nSBC Value\nGeographic Coordinates'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='A proper Coordinate Reference System (CRS) must be selected.\n\nIncorrect CRS can lead to:\n\nWrong distance calculations\nIncorrect area calculations\nSpatial analysis errors'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Therefore, selecting the correct CRS is essential for accurate GIS analysis.\n\n5.3 Creation of Base Map\n\nA base map is added to provide geographical reference.\n\nCommonly used base maps include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='OpenStreetMap\nSatellite imagery\n\nThe base map helps identify:\n\nRoads\nBuildings\nExisting infrastructure\nBorehole locations'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='It also defines the study area boundary and improves readability of the final SBC maps.\n\n5.4 Spatial Interpolation of SBC Values'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Since boreholes exist only at discrete locations, interpolation is required to estimate SBC values between them.\n\nThe study uses the Inverse Distance Weighting (IDW) interpolation method.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Principle of IDW\nNearby points have greater influence.\nDistant points have less influence.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='IDW generates a continuous surface showing the spatial variation of Soil Bearing Capacity across the study area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The resulting map estimates SBC values for locations where no borehole investigations have been conducted.\n\nNext (Part 3) will include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='5.5 Classification and Zoning of SBC\n5.6 Generation of SBC Maps\nResults and Discussion\nConclusion\nFuture Scope\nNovelty Table\nReferences\n\n5.5 Classification and Zoning of Soil Bearing Capacity (SBC)'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='After completing the spatial interpolation process using the Inverse Distance Weighting (IDW) method, the estimated Soil Bearing Capacity (SBC) values are classified into different categories'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='categories according to their engineering significance. Classification is an essential step because it transforms numerical SBC values into meaningful zones that engineers can easily interpret during'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='interpret during planning and design.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The interpolated SBC values are generally divided into three major classes:\n\n1. Low Soil Bearing Capacity Zone'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='These regions indicate weak soil conditions. The soil present in these areas has a limited ability to support structural loads. Construction on such soils may lead to excessive settlement, uneven'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='settlement, uneven foundation movement, or structural failure if appropriate precautions are not taken.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Characteristics:\n\nSoft soil deposits\nPoor load carrying capacity\nHigh settlement potential\nUnsuitable for shallow foundations without soil improvement\n\nRecommended foundation systems include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Pile foundations\nSoil stabilization techniques\nGround improvement methods\nDeep foundations\n2. Medium Soil Bearing Capacity Zone\n\nThese areas possess moderate soil strength.\n\nCharacteristics include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Moderate settlement\nSuitable for medium-sized structures\nRequires proper structural design\nEconomical foundation options\n\nSuitable foundation systems include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Isolated footing\nCombined footing\nStrip footing\nRaft foundation (depending upon loading)\n3. High Soil Bearing Capacity Zone\n\nThese regions possess strong and stable soils.\n\nCharacteristics:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Characteristics:\n\nHigh load-carrying capacity\nLess settlement\nStable ground conditions\nSuitable for heavy construction\n\nRecommended foundation systems:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Shallow foundations\nIsolated footing\nCombined footing\nRaft foundation\n\nThese zones significantly reduce construction cost because expensive ground improvement methods are generally unnecessary.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Importance of SBC Zoning\n\nPreparation of SBC zoning maps provides several engineering advantages:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Quick identification of weak soil regions.\nEasy selection of suitable foundation type.\nBetter planning of future construction.\nReduced preliminary investigation cost.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Improved visualization of spatial variation.\nFaster decision-making by engineers and planners.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The zoning maps generated through QGIS act as decision-support tools during the early planning stage of construction projects.\n\n5.6 Generation of SBC Maps and GIS Outputs'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The final output of this study is the generation of various thematic maps representing the spatial distribution of Soil Bearing Capacity across the study area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Several GIS outputs are produced after completion of spatial analysis.\n\n1. Soil Bearing Capacity Distribution Map'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='This map displays the variation of SBC throughout the study area using different colors representing different bearing capacities.\n\nThe map clearly identifies:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Weak soil regions\nMedium-strength soil regions\nStrong soil regions\n\nThis map serves as the primary output of the research.\n\n2. Contour Map\n\nContour maps represent continuous variation of SBC values.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Benefits include:\n\nEasy visualization of gradual changes.\nIdentification of transition zones.\nBetter understanding of spatial trends.\n3. Zoning Map\n\nThe zoning map classifies the study area into:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Low SBC Zone\nMedium SBC Zone\nHigh SBC Zone\n\nThis map assists engineers in selecting suitable foundation systems before conducting detailed investigations.\n\n4. Decision Support Map'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The GIS-generated outputs become valuable decision-support tools because they allow engineers to:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Compare multiple construction sites.\nSelect economically suitable locations.\nReduce uncertainty during planning.\nIdentify areas requiring detailed geotechnical investigation.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6. Results and Discussion'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The GIS-based analysis successfully generated Soil Bearing Capacity maps for the selected study area.\n\nThe generated maps demonstrate that Soil Bearing Capacity is not constant throughout the area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Instead, significant spatial variation exists due to changes in:\n\nSoil type\nGeological conditions\nSubsurface layers\nMoisture content\nMajor Observations\nVariation in SBC'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated SBC map indicates that different parts of the study area possess different load-carrying capacities.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Some locations exhibit very low SBC values, while others possess relatively high bearing capacities.\n\nThis confirms that soil conditions vary considerably within the same geographical region.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Low SBC Regions\n\nAreas classified as low SBC indicate weak soil conditions.\n\nConstruction in these areas requires special attention.\n\nPossible engineering solutions include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Soil replacement\nSoil stabilization\nStone columns\nPile foundations\nDeep foundations\n\nWithout appropriate treatment, these areas may experience:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Differential settlement\nFoundation failure\nCracking of buildings\nStructural instability\nMedium SBC Regions\n\nThese regions are suitable for ordinary construction after proper structural design.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Depending upon loading conditions, engineers may adopt:\n\nStrip footing\nCombined footing\nIsolated footing\nRaft foundation\nHigh SBC Regions\n\nThese regions represent strong soil conditions.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Advantages include:\n\nHigher bearing capacity\nLower settlement\nBetter structural stability\nReduced foundation cost\n\nThese locations are ideal for shallow foundation systems.\n\nSpatial Variability'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='One of the most significant outcomes of this research is the visualization of spatial variability.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Instead of relying only on discrete borehole values, engineers can now understand how SBC changes continuously across the entire study area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='This provides a much clearer understanding of underground conditions.\n\nImportance of GIS\n\nThe research demonstrates several advantages of GIS:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Rapid spatial analysis\nEasy visualization\nContinuous estimation of SBC\nBetter planning\nCost reduction\nTime saving'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated maps become valuable tools during preliminary planning before expensive field investigations are conducted.\n\nLimitation\n\nThe accuracy of interpolation depends mainly on:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Number of boreholes\nDistribution of boreholes\nQuality of input data\n\nIf boreholes are sparse, interpolation uncertainty increases.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Therefore, GIS-based estimation should be considered as a preliminary planning tool rather than a replacement for detailed soil investigation.\n\n7. Conclusion'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='7. Conclusion\n\nThe present research demonstrates the successful application of Geographic Information Systems (GIS) for estimating Soil Bearing Capacity using borehole and geotechnical data.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='QGIS proved to be an effective platform for:\n\nManaging geotechnical information\nPerforming spatial analysis\nVisualizing soil properties\nEstimating SBC values at untested locations'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated SBC maps clearly illustrate the spatial variation of soil strength across the study area.\n\nThese maps help engineers:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Select suitable foundation types.\nIdentify weak soil zones.\nReduce construction risk.\nImprove project planning.\nSave time and investigation cost.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The research confirms that GIS can significantly improve preliminary foundation planning while reducing dependence on expensive field investigations.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='However, GIS estimation should always be supported by detailed geotechnical investigations before final foundation design.\n\n7.2 Future Scope'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='7.2 Future Scope\n\nAlthough the present methodology provides reliable preliminary results, several improvements are possible in future research.\n\nIntegration of Machine Learning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Artificial Intelligence and Machine Learning can be integrated with GIS to predict SBC more accurately.\n\nPossible ML algorithms include:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Random Forest\nSupport Vector Machine (SVM)\nArtificial Neural Network (ANN)\nXGBoost\nDeep Learning Models\n\nThese models can learn from existing borehole datasets and predict SBC at new locations.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Additional Borehole Data\n\nIncreasing the number of boreholes will improve interpolation accuracy.\n\nMore data points reduce uncertainty and provide more reliable spatial estimation.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Geophysical Survey Integration\n\nFuture work can combine:\n\nElectrical Resistivity Survey\nSeismic Refraction Survey\nGround Penetrating Radar (GPR)\n\nwith borehole information.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='This improves subsurface characterization and reduces uncertainty.\n\n3D Subsurface Modeling\n\nFuture GIS applications can generate complete three-dimensional subsurface models showing:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Soil layers\nRock layers\nBearing Capacity variation with depth\n\nThese models help engineers visualize underground conditions more effectively.\n\nWeb-Based GIS Platform'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='A web GIS portal can be developed where users simply:\n\nSelect a location on a map\nEnter latitude and longitude\nInstantly obtain estimated SBC values\n\nSuch systems will benefit:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Engineers\nArchitects\nContractors\nGovernment agencies\nUrban planners\nLarge-Scale Application\n\nThe developed methodology can be extended to:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Entire cities\nDistricts\nStates\nNational infrastructure projects\n\nThis will support large-scale planning and decision-making.\n\nNovelty and Uniqueness of the Present Study'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The present study introduces several improvements over previous GIS-based research:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Integration of borehole data with GIS-based spatial analysis.\nContinuous SBC estimation across the entire study area instead of only discrete borehole locations.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='GIS-based thematic maps and zoning for foundation planning.\nQGIS-based interpolation workflow using open-source software.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Practical, application-oriented methodology suitable for real engineering projects.\nDecision-support system for preliminary foundation planning and site selection.\nReferences'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='References\nDivya Priya et al. – Application of GIS Techniques in Geotechnical Engineering for Spatial Analysis of Soil Properties.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Civelekler, M., et al. (2023) – GIS-Based Three-Dimensional Subsurface Modeling Using Borehole and Geophysical Data.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='KSCE Journal of Civil Engineering – GIS-Based Analysis of Geotechnical Parameters Using Borehole Data.\nDas, B. M. (2010) – Principles of Geotechnical Engineering.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Bowles, J. E. (1996) – Foundation Analysis and Design.\nBurrough, P. A., & McDonnell, R. A. (1998) – Principles of Geographical Information Systems.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='5.5 Classification and Zoning of SBC'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='After performing the Inverse Distance Weighting (IDW) interpolation, the estimated Soil Bearing Capacity (SBC) values are classified into different categories such as Low, Medium, and High Bearing'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='and High Bearing Capacity. This classification helps engineers understand the strength characteristics of the soil across the entire study area. Instead of looking at individual borehole values, the'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='values, the classification converts the interpolated data into meaningful engineering zones that are easier to interpret and use for planning purposes.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The Low SBC Zone represents weak soil conditions where the bearing capacity is insufficient to support heavy structural loads without excessive settlement. These areas generally require special'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='require special foundation treatment such as deep foundations, pile foundations, soil stabilization, or ground improvement techniques before construction can begin.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The Medium SBC Zone represents soils having moderate bearing capacity. These regions are generally suitable for residential and medium-rise buildings using properly designed shallow foundations.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='foundations. However, detailed geotechnical investigation is still recommended before finalizing the foundation design.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The High SBC Zone indicates strong and stable soil capable of safely supporting higher structural loads. These areas are generally considered suitable for shallow foundations such as isolated'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='such as isolated footings, strip footings, combined footings, or raft foundations. Construction costs are usually lower in these regions because little or no ground improvement is required.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Using QGIS, these classifications are displayed through different colours on thematic maps, allowing engineers to quickly identify suitable and unsuitable construction zones. The generated zoning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='generated zoning maps provide a clear understanding of the spatial variation of soil strength throughout the study area and act as an effective decision-support tool during the preliminary planning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='planning stage of civil engineering projects.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='5.6 Generation of SBC Maps and Outputs'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The final stage of the GIS analysis involves generating different thematic maps that represent the spatial distribution of Soil Bearing Capacity across the study area. These maps are produced after'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='are produced after completing data preparation, spatial interpolation, and classification.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The primary output is the Soil Bearing Capacity Distribution Map, which displays the estimated SBC values throughout the study area. Areas having similar bearing capacities are represented using'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='represented using different colour ranges, making it easy to identify regions with weak, moderate, and strong soils.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='In addition to the distribution map, contour maps are generated to show the gradual variation of Soil Bearing Capacity. Contour maps help engineers visualize how SBC changes continuously from one'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='from one location to another instead of changing abruptly between boreholes.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Another important output is the SBC Zoning Map, which divides the study area into different engineering zones according to their bearing capacity. These zoning maps provide valuable information for'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='information for selecting appropriate foundation systems and identifying areas where additional soil investigation may be required.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The GIS outputs produced during this research serve as effective decision-support tools for civil engineers, architects, planners, and infrastructure developers. By examining these maps, engineers'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='maps, engineers can understand the spatial variation of soil strength, identify favourable construction sites, estimate foundation requirements, and reduce unnecessary field investigations during the'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='during the initial planning stage of projects.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6. Results and Discussion'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The GIS-based methodology successfully generated Soil Bearing Capacity distribution maps for the selected study area using borehole data and spatial interpolation techniques.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated SBC maps clearly indicate that Soil Bearing Capacity varies significantly across the study area due to differences in soil type, geological conditions, and subsurface characteristics.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='characteristics. Instead of obtaining information only at discrete borehole locations, the GIS-based approach provides continuous estimation of Soil Bearing Capacity across the entire area.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The analysis shows that areas having Low Soil Bearing Capacity may experience excessive settlement if shallow foundations are used. Such regions may require excavation, deep foundations, pile'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='foundations, pile foundations, soil stabilization, or other ground improvement techniques before construction activities begin.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Areas possessing Medium to High Soil Bearing Capacity are generally suitable for shallow foundation systems such as isolated footings and raft foundations. These regions exhibit better load-carrying'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='load-carrying capacity and relatively stable soil conditions, making them favourable for construction.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='One of the major advantages observed during this study is the visualization of spatial variability in Soil Bearing Capacity. Instead of relying solely on numerical borehole values, engineers can now'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='engineers can now easily identify different foundation zones through GIS-generated thematic maps.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The results demonstrate that GIS-based Soil Bearing Capacity mapping significantly improves preliminary planning by allowing engineers to identify favourable construction zones quickly. It also'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='quickly. It also reduces uncertainty during the early design stage and minimizes the overall cost and time associated with extensive geotechnical investigations.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='However, the study also highlights that the accuracy of GIS-based estimation depends on the quality, quantity, and spatial distribution of borehole data. Areas with fewer boreholes may produce less'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='may produce less reliable interpolation results. Therefore, GIS-based estimation should be considered a preliminary planning tool rather than a replacement for detailed field investigations and'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='investigations and laboratory testing.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='7. Conclusion\n\nThe present research demonstrates the successful application of Geographic Information Systems (GIS) for estimating Soil Bearing Capacity using borehole and geotechnical information.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='QGIS proved to be an efficient open-source GIS platform for managing, analyzing, visualizing, and interpreting Soil Bearing Capacity data across the entire study area. The developed GIS methodology'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='GIS methodology enables approximate estimation of SBC values at locations where direct soil investigation data is unavailable.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The generated Soil Bearing Capacity Distribution Maps and Zoning Maps effectively illustrate the spatial variation of soil strength and provide valuable support for preliminary foundation planning.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='planning. Engineers, planners, and design professionals can use these maps to identify weak soil zones, select suitable foundation types, reduce investigation costs, and improve construction'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='construction planning.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The research confirms that GIS-based Soil Bearing Capacity mapping is a practical, economical, and efficient approach for preliminary geotechnical assessment. However, detailed field investigations'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='investigations remain essential before final foundation design and construction decisions are made.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='7.2 Future Scope\n\nAlthough the present GIS methodology provides useful preliminary results, several opportunities exist for improving the system in future research.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Increasing the number of borehole locations and laboratory test results will significantly improve the accuracy of Soil Bearing Capacity estimation. As more geotechnical data becomes available,'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='becomes available, spatial interpolation techniques will generate more reliable results.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Future research can integrate geophysical investigation methods such as Electrical Resistivity Surveys and Seismic Surveys with borehole data. Combining these datasets within GIS will improve'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='GIS will improve subsurface characterization and reduce uncertainty regarding underground conditions.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Advanced spatial interpolation techniques and Machine Learning models can also be incorporated to improve prediction accuracy. Artificial Intelligence algorithms can analyze complex relationships'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='relationships between soil properties, borehole information, depth, and geographical location to estimate Soil Bearing Capacity more accurately than conventional interpolation methods.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Another important future development is the creation of 3D subsurface models that represent soil layers and Soil Bearing Capacity variation with depth. Such models will provide engineers with a'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='engineers with a better understanding of underground conditions and improve foundation design decisions.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The development of web-based GIS platforms will allow engineers, planners, government agencies, and consultants to access real-time geotechnical information through online applications. Users will be'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Users will be able to select any location on the map and instantly obtain estimated Soil Bearing Capacity values.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Finally, the proposed methodology can be extended to larger cities, districts, states, and national infrastructure projects, creating comprehensive GIS databases for efficient geotechnical planning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='planning and sustainable infrastructure development.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Table 2: Novelty and Uniqueness of the Present Study\nSr. No.\tAspect\tPrevious Studies\tPresent Study'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='1\tData Usage\tMostly limited to borehole data\tIntegration of borehole data with GIS-based spatial analysis\n2\tVisualization\t2D maps or tabular representation\tGIS-based thematic maps and SBC zoning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='3\tSpatial Coverage\tSBC values only at discrete borehole locations\tContinuous SBC estimation across the entire study area\n4\tMethodology\tConventional analysis methods\tGIS-based interpolation using QGIS'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='5\tDecision Support\tLimited planning support\tSBC zoning maps for preliminary foundation planning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6\tPractical Application\tMostly academic studies\tApplication-oriented methodology suitable for real engineering projects\nReferences'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='References\nDivya Priya et al. – Application of GIS Techniques in Geotechnical Engineering for Spatial Analysis of Soil Properties.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Civelekler, M., et al. (2023). GIS-Based Three-Dimensional Subsurface Modeling Using Borehole and Geophysical Data.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='KSCE Journal of Civil Engineering – GIS-Based Analysis of Geotechnical Parameters Using Borehole Data.\nDas, B. M. (2010). Principles of Geotechnical Engineering.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Bowles, J. E. (1996). Foundation Analysis and Design.\nBurrough, P. A., & McDonnell, R. A. (1998). Principles of Geographical Information Systems.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='GIS Based Estimation of Soil Bearing Capacity Using Borehole and Geophysical Data\n\n1Jayant Raut, 2Ananya Budhwat, 3Ishant Rai, 4Laxmikant Nimbulkar, 5Mahesh Deshmukh,\n6Om Kadasne'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='1-6Department of Civil Engineering, Yeshawantrao Chavan College Of Engineering, Nagpur-441110.\nEmail: jmr100@rediffmail.com, laxmikantnimbulkar2@gmail.com'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Abstract— One of the most critical parameters of an engineering foundation is the bearing capacity of soil (i.e., soil bearing capacity). Having an accurate estimate of the soil bearing capacity of'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='bearing capacity of the ground is necessary for designing civil engineering structures safely and efficiently. Traditional methods of determining the soil bearing capacity of the ground involved'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='the ground involved performing borehole investigations and laboratory tests. Although these methods are reliable, they take excessive amounts of time to obtain results (i.e., borehole investigations)'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content="investigations) and are expensive due to the equipment and personnel required. Furthermore, soil bearing capacity values will frequently not be obtainable in many areas of a project's site."),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Geographic Information Systems (GIS) provide an efficient means of storing, manipulating, and analyzing spatially referenced data. By integrating borehole and geotechnical data with GIS'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='data with GIS software, an approximate value of soil bearing capacity can be estimated at locations that have not been tested for this parameter using techniques for interpolating between spatial'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='between spatial data points. This study used QGIS as a GIS tool to develop a GIS-based map showing a distribution of soil bearing capacity in the study area. This was accomplished by collecting soil'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='by collecting soil bearing capacity data, creating spatial datasets, interpolating soil bearing capacity data, and creating visualizations of the results.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The final product from this study will be a GIS-generated map of the location of low, medium, and high soil bearing capacities that can be used as a basis for preliminary planning of'),
# ...
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='representation of underground conditions compared to traditional two-dimensional methods. Another important conclusion of the study is that integration of Artificial Intelligence and Machine Learning'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Machine Learning techniques with GIS has significant future potential in geotechnical engineering. AI-based systems can automatically analyze geotechnical datasets and predict Soil Bearing Capacity'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Bearing Capacity with improved speed and accuracy. Such smart systems may become valuable tools for future infrastructure planning and geotechnical decision-support applications.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The present work also demonstrated that open-source software such as QGIS can be effectively used for academic and practical geotechnical applications without the need for expensive'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='need for expensive proprietary GIS software. This makes GIS-based geotechnical analysis more accessible for researchers, students, and engineering professionals.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Although the present study focused mainly on preliminary SBC estimation, the developed methodology can be extended further by:\n•\tUsing larger datasets \n•\tApplying advanced geostatistical techniques'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='•\tIntegrating geophysical survey data \n•\tDeveloping AI-based predictive models \n•\tCreating web-based GIS platforms'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='In conclusion, the present project successfully achieved its objectives and demonstrated that GIS-based estimation of Soil Bearing Capacity is an effective approach for spatial analysis,'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='spatial analysis, visualization, and preliminary foundation planning. The methodology developed in this study can support future research and infrastructure development projects by improving'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='by improving efficiency, reducing investigation costs, and enhancing decision-making in geotechnical engineering.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='CHAPTER 6:\nAPPENDIX'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The appendix section contains supporting information, datasets, workflow details, and supplementary materials used during the project work. The appendix provides additional technical details'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='technical details regarding borehole data, GIS processing steps, SBC classification, and methodology adopted for the study.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The information included in this section supports the analysis and results presented in previous chapters and helps in understanding the practical implementation of the GIS-based'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='of the GIS-based methodology used for estimation of Soil Bearing Capacity.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6.1 Borehole Data'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Borehole investigation data formed the primary input dataset for the present study. The data were collected from available geotechnical investigation reports and soil testing records.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='testing records. Borehole investigations provide detailed information regarding subsurface soil conditions and engineering properties required for foundation analysis and design.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The collected data included:\n•\tBorehole identification number \n•\tLatitude and longitude coordinates \n•\tBorehole depth \n•\tSoil Bearing Capacity (SBC) \n•\tSoil classification details'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The geographic coordinates corresponding to each borehole location were extracted using Google Earth Pro and verified before importing into QGIS software. The borehole data were arranged'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='data were arranged systematically in Microsoft Excel and converted into CSV format for spatial analysis.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The quality and reliability of GIS-based interpolation depend greatly on the accuracy and spatial distribution of borehole data The borehole points were later plotted in QGIS to generate'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='in QGIS to generate SBC distribution maps and interpolation surfaces.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6.2 QGIS Workflow'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='QGIS was used as the primary GIS software platform for spatial analysis, map generation, interpolation, and visualization during the project work. The complete workflow adopted in QGIS is'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='adopted in QGIS is summarized below.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Step 1: Preparation of Data\nThe borehole and SBC data were organized in Microsoft Excel. Separate columns were created for:\n•\tBorehole ID \n•\tLatitude \n•\tLongitude \n•\tSBC value \n•\tBorehole depth'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='•\tBorehole depth \nThe file was saved in CSV format for compatibility with QGIS.\nStep 2: Import of CSV File into QGIS'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The CSV file containing borehole coordinates was imported using the “Add Delimited Text Layer” tool. Latitude and longitude values were assigned as coordinate fields to create point layers.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Step 3: Addition of Base Map\nOpenStreetMap and satellite imagery layers were added to provide geographical context and improve visualization of borehole locations.\nStep 4: Creation of Point Layer'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The imported coordinate data were converted into spatial point layers representing borehole positions within the study area.\nStep 5: Spatial Interpolation'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The Inverse Distance Weighting (IDW) interpolation tool was used to estimate Soil Bearing Capacity values at untested locations and generate continuous raster surfaces.\nStep 6: Generation of SBC Maps'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Different thematic maps were generated, including:\n•\tSBC distribution map \n•\tSBC contour map \n•\tSBC zoning map \n•\tHeat map \nStep 7: 3D Visualization'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='QGIS 3D visualization tools were used to create three-dimensional views of borehole and SBC data for better interpretation of subsurface conditions.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The QGIS workflow significantly improved efficiency of spatial analysis and visualization during the project.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6.3 SBC Classification Table'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The interpolated Soil Bearing Capacity values were classified into different categories to identify weak, moderate, and strong soil zones within the study area. This classification helps'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='helps engineers in selecting suitable foundation systems during preliminary planning stages.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Table 6.3. SBC Classification Table\nSBC Range (KN/m²)\tSoil Condition\tFoundation Recommendation\nBelow 100\tVery Weak Soil\tDeep Foundation\n100 – 150\tWeak Soil\tRaft Foundation'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='150 – 200\tModerate Soil\tCombined Footing\n200 – 300\tStrong Soil\tIsolated Footing\nAbove 300\tVery Strong Soil\tShallow Foundation\nThe generated SBC zoning maps were useful for:'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='•\tSite suitability analysis \n•\tFoundation planning \n•\tIdentification of weak soil regions \n•\tPreliminary geotechnical assessment'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The classification also improved visualization and interpretation of interpolation results generated in QGIS.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='6.4 Methodology Flowchart'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The methodology adopted in the present study involved systematic steps beginning from data collection and ending with GIS-based spatial analysis and visualization of Soil Bearing Capacity.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The methodology flowchart is shown below:\nCollection of Borehole Data\n↓\nPreparation of Excel Database\n↓\nExtraction of Coordinates using Google Earth Pro\n↓\nConversion into CSV Format\n↓'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='↓\nImport of Data into QGIS\n↓\nCreation of Borehole Point Layer\n↓\nAddition of Base Map\n↓\nSpatial Interpolation using IDW\n↓\nGeneration of SBC Maps\n↓\n3D Visualization of SBC Data\n↓'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='↓\nResult Analysis and Interpretation'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The methodology adopted in this project provided a systematic and efficient approach for spatial estimation and visualization of Soil Bearing Capacity using GIS techniques.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='The workflow can be further extended for:\n•\tLarger study areas \n•\tAdvanced interpolation techniques \n•\tMachine Learning integration \n•\tReal-time geotechnical analysis \n•\tWeb GIS applications'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='CHAPTER 7:\nREFERENCES\n\n7.1 References'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[1].\tB. M. Das, Principles of Geotechnical Engineering, 7th Edition, Cengage Learning India Pvt. Ltd., New Delhi, 2010.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[2].\tJ. E. Bowles, Foundation Analysis and Design, 5th Edition, McGraw-Hill International Editions, New York, 1996.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[3].\tM. Civelekler, A. Demir, and H. Kalkan, “GIS-Based Three-Dimensional Subsurface Modeling Using Borehole and Geophysical Data,” Environmental Earth Sciences, Springer, vol. 82, no. 3, pp. 1–15,'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='no. 3, pp. 1–15, 2023.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[4].\tDivya Priya B. and G. R. Dodagoudar, “An Integrated Geotechnical Database and GIS for 3D Subsurface Modelling: Application to Chennai City, India,” Arabian Journal of Geosciences, vol. 11, no.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='vol. 11, no. 2, pp. 1–14, 2018.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[5].\tMichael Moses Apeh and Alias Abdul Rahman, “A Review of 3D Spatial Data Models for Surface and Subsurface Integration,” ISPRS International Journal of Geo-Information, vol. 11, no. 4, pp. 1–20,'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='no. 4, pp. 1–20, 2022.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[6].\tMar Alcaraz and Enric Vázquez-Suñé, “HEROS3D: 3D Geological, Hydrogeological and Thermal Modelling System for the Management of Groundwater Resources,” Computers & Geosciences, vol. 90, pp.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='vol. 90, pp. 1–12, 2016.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[7].\tKaterina Kavoura, Maria Konstantopoulou, and Co-Researchers, “3D Subsurface Geological Modelling Using GIS, Remote Sensing and Borehole Data Along Transportation Corridors,” Engineering Geology'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='Engineering Geology Journal, vol. 45, no. 6, pp. 245–258, 2016.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[8].\tKSCE Journal of Civil Engineering, “GIS-Based Analysis of Geotechnical Parameters Using Spatial Interpolation Techniques,” Springer Publications, 2020.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[9].\tP. A. Burrough and R. A. McDonnell, Principles of Geographical Information Systems, Oxford University Press, Oxford, 1998.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[10].\tIan Heywood, Sarah Cornelius, and Steve Carver, An Introduction to Geographical Information Systems, Pearson Education, 2006.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[11].\tQGIS Development Team, QGIS Geographic Information System User Guide, Open Source Geospatial Foundation Project, 2025. \n[12].\tGoogle Earth Pro User Manual, Google Inc., California, USA, 2025.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[13].\tASTM D1194-94, Standard Test Method for Bearing Capacity of Soil for Static Load and Spread Footings, ASTM International, Pennsylvania, USA.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[14].\tIS 6403:1981, Code of Practice for Determination of Bearing Capacity of Shallow Foundations, Bureau of Indian Standards (BIS), New Delhi.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[15].\tIS 1892:1979, Code of Practice for Subsurface Investigation for Foundations, Bureau of Indian Standards (BIS), New Delhi.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[16].\tPunmia, B. C., Ashok Kumar Jain, and Arun Kumar Jain, Soil Mechanics and Foundations, Laxmi Publications, New Delhi, 2017.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[17].\tS. K. Garg, Soil Mechanics and Foundation Engineering, Khanna Publishers, New Delhi, 2012. \n[18].\tC. Venkatramaiah, Geotechnical Engineering, New Age International Publishers, New Delhi, 2006.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[19].\tDavid Cowen, “GIS Versus CAD Versus DBMS: What Are the Differences?”, Photogrammetric Engineering and Remote Sensing, vol. 54, no. 11, pp. 1551–1555, 1988.'),
#  Document(metadata={'source': 'qgissafebearingcapcity.txt'}, page_content='[20].\tTomlinson and Boorman, Foundation Design and Construction, Pearson Education, London, 2001.\npip')]

# %%
# If finalDocuments is a list of Document objects:
text = [doc.page_content for doc in finalDocuments]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
pip install langchain_huggingface
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.4.9)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.10.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.5.0)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.2

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db

# %%
pip install faiss-gpu
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (26.2)
# Collecting nvidia-cuda-runtime-cu12<13,>=12.6 (from faiss-gpu)
#   Downloading nvidia_cuda_runtime_cu12-12.9.79-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cublas-cu12<13,>=12.6 (from faiss-gpu)
#   Downloading nvidia_cublas_cu12-12.9.2.10-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-curand-cu12<11,>=10.3.7 (from faiss-gpu)
#   Downloading nvidia_curand_cu12-10.3.10.19-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc-cu12 (from nvidia-cublas-cu12<13,>=12.6->faiss-gpu)
#   Downloading nvidia_cuda_nvrtc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Downloading faiss_gpu-1.14.3-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (134.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.9.2.10-py3-none-manylinux_2_27_x86_64.whl (581.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.2/581.2 MB 858.9 kB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.9.79-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 81.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.10.19-py3-none-manylinux_2_27_x86_64.whl (68.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (89.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 MB 8.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cublas-cu12, faiss-gpu
# Successfully installed faiss-gpu-1.14.3 nvidia-cublas-cu12-12.9.2.10 nvidia-cuda-nvrtc-cu12-12.9.86 nvidia-cuda-runtime-cu12-12.9.79 nvidia-curand-cu12-10.3.10.19

# %%
query = input("ask any question ? : ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# ask any question ? : what is qgis
# QGIS (Quantum Geographic Information System) is a widely used open source GIS software for mapping and spatial analysis applications. QGIS has powerful tools for creating maps, point layers, contour
# QGIS was used as the primary GIS software platform for spatial analysis, map generation, interpolation, and visualization during the project work. The complete workflow adopted in QGIS is
# QGIS is free and open source software and one of the major advantages of QGIS is that it is freely available for academic and research purposes. QGIS also has plugins and tools for advanced spatial
# 3.3.1	QGIS
# QGIS (Quantum Geographic Information System) is an open-source GIS software used for spatial data analysis and mapping. It provides tools for:
# •	Point layer creation
